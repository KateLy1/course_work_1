# %%
import pandas as pd

# %%
data = pd.read_excel('Книга3.xlsx')

# %%
#Оставляем строки, в которых более 3-х пробелов, то есть более 4 слов
data_f = data[data['Отзыв'].apply(lambda x: str(x).count(' ') > 3)].reset_index(drop=True)

# %%
data_f
# Out:
#                                                   Отзыв
# 0     Кто пишет, что это не центр: а что это?😁 Пешко...
# 1     Если выбирать квартиру со стороны Красноармейс...
# 2     Это не центр…. Обводник это многополосная доро...
# 3     Какой центр??? Полный отстой напротив красны т...
# 4           Следует обратить внимание перед покупкой ->
# ...                                                 ...
# 3416  Можно поставить "0" звезд!? Где дороги!!! Куда...
# 3417  Никакой инфраструктуры. Привет дорога "полоса ...
# 3418  Ни о какокой доступности речи не идёт, очередн...
# 3419  Дом возле взлетной полосы. Дизайн дома - очере...
# 3420  Горд сказка? Город мечта! Но попав ты в эти се...
#
# [3421 rows x 1 columns]

# %%
data_f.to_csv('reviews11.csv', index=False, encoding='utf-8-sig')
